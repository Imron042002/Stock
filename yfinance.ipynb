# %%
import yfinance as yf

# เลือกหุ้นไทย เช่น AOT.BK (Airports of Thailand)
symbol = "GULF.BK"
ticker = yf.Ticker(symbol)

# ดึงข้อมูลพื้นฐาน
info = ticker.info

# แสดงข้อมูลสำคัญ
print(f"🔎 ข้อมูลหุ้น {info.get('longName')}")
print(f"Symbol: {info.get('symbol')}")
print(f"Exchange: {info.get('exchange')}")
print(f"Last Price: {info.get('regularMarketPrice')}")
print(f"Day High: {info.get('dayHigh')}")
print(f"Day Low: {info.get('dayLow')}")
print(f"Change: {info.get('regularMarketChange')} ({info.get('regularMarketChangePercent')}%)")
print(f"Volume: {info.get('volume')}")
print(f"EPS: {info.get('trailingEps')}")
print(f"P/E Ratio: {info.get('trailingPE')}")
print(f"Dividend Yield: {info.get('dividendYield')}")
print(f"Implied Volatility: {info.get('impliedVolatility')}")
# Out:
# 🔎 ข้อมูลหุ้น Gulf Energy Development Public Company Limited
# Symbol: GULF.BK
# Exchange: SET
# Last Price: 47.5
# Day High: 48.75
# Day Low: 47.25
# Change: -0.75 (-1.5544041%)
# Volume: 29305107
# EPS: 1.55
# P/E Ratio: 30.645163
# Dividend Yield: 2.09
# Implied Volatility: None

# %%
import yfinance as yf
import pandas as pd

# ดึงข้อมูลหุ้นรายตัว
stock = yf.Ticker("AOT.BK")

# ดึงข้อมูลพื้นฐานของหุ้น
fundamental_data = stock.info

# แสดงข้อมูลพื้นฐาน
print("ข้อมูลพื้นฐานของหุ้น:")
print(fundamental_data)

# สร้าง DataFrame จากข้อมูลที่เลือก
fundamental_df = pd.DataFrame({
    "Metric": ["PE Ratio", "Market Cap", "EPS", "Beta", "Dividend Yield"],
    "Value": [
        fundamental_data.get("trailingPE", "N/A"),
        fundamental_data.get("marketCap", "N/A"),
        fundamental_data.get("epsTrailingTwelveMonths", "N/A"),
        fundamental_data.get("beta", "N/A"),
        fundamental_data.get("dividendYield", "N/A")
    ]
})

# เรียงลำดับข้อมูลตาม Metric
fundamental_df = fundamental_df.sort_values(by="Metric")

# แสดง DataFrame ที่เรียงลำดับแล้ว
print("\nDataFrame ที่เรียงลำดับแล้ว:")
print(fundamental_df)
# Out:
# ข้อมูลพื้นฐานของหุ้น:
# {'address1': 'No. 333, Cherdwutagard Road', 'address2': 'Srikan Don Mueang', 'city': 'Bangkok', 'zip': '10210', 'country': 'Thailand', 'phone': '66 2 535 1111', 'fax': '66 2 531 5559', 'website': 'https://www.airportthai.co.th', 'industry': 'Airports & Air Services', 'industryKey': 'airports-air-services', 'industryDisp': 'Airports & Air Services', 'sector': 'Industrials', 'sectorKey': 'industrials', 'sectorDisp': 'Industrials', 'longBusinessSummary': 'Airports of Thailand Public Company Limited, together with its subsidiaries, engages in the airport business in Thailand. The company operates through Airport Management Business, Hotel Business, Ground Aviation Services, Security Business, and Project on Perishable Goods Business segments. It operates six international airports, including Suvarnabhumi Airport, Don Mueang International Airport, Chiang Mai International Airport, Hat Yai International Airport, Phuket International Airport and Mae Fah Luang - Chiang Rai International Airport. The company is involved in the hotel and restaurant business; and operation and management of the project on perishable goods at Suvarnabhumi Airport. In addition, it offers ground equipment, security services, and manages projects, as well as ground, warehouse, and cleaning services. Airports of Thailand Public Company Limited was founded in 1979 and is headquartered in Bangkok, Thailand.', 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Kerati  Kijmanawat', 'age': 45, 'title': 'President & Secretary of the Board of Directors', 'yearBorn': 1979, 'fiscalYear': 2024, 'totalPay': 1202573, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Chenwit  Musikarat', 'age': 56, 'title': 'Senior Executive Vice President of Accounting & Finance and CFO', 'yearBorn': 1968, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Boonploog  Noinamkham', 'age': 54, 'title': 'Chief Accountant & VP of Accounting Department', 'yearBorn': 1970, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Chadanisa  Chumnanvej', 'age': 55, 'title': 'Senior Executive Vice President of Human Resources & Administration', 'yearBorn': 1969, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Napha  Limwonguyuti', 'title': 'VP of Investor Relations Department and Chief Investor Relations Officer', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Lieutenant Jueathip  Plathong', 'age': 56, 'title': 'Chief Compliance Officer and VP of Corporate Compliance & Anti-Corruption Department', 'yearBorn': 1968, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Sirote  Duangratana', 'age': 56, 'title': 'Senior Executive Vice President of Business Development & Marketing', 'yearBorn': 1968, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Anake  Teeraviwatchai', 'age': 54, 'title': 'Senior Executive Vice President of Corporate Strategy', 'yearBorn': 1970, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Kittipoj  Venunantana', 'age': 54, 'title': 'Senior Executive Vice President of Digital Technology & Innovation', 'yearBorn': 1970, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Patcharawalai  Tunprawat', 'age': 43, 'title': 'Executive Vice President of Accounting & Finance-2', 'yearBorn': 1981, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}], 'compensationAsOfEpochDate': 1735603200, 'irWebsite': 'http://aot.listedcompany.com/home.html', 'executiveTeam': [], 'maxAge': 86400, 'priceHint': 2, 'previousClose': 43.25, 'open': 43.25, 'dayLow': 41.75, 'dayHigh': 43.5, 'regularMarketPreviousClose': 43.25, 'regularMarketOpen': 43.25, 'regularMarketDayLow': 41.75, 'regularMarketDayHigh': 43.5, 'dividendRate': 0.79, 'dividendYield': 1.83, 'exD ...
#
# DataFrame ที่เรียงลำดับแล้ว:
#            Metric         Value
# 3            Beta  3.600000e-01
# 4  Dividend Yield  1.830000e+00
# 2             EPS  1.390000e+00
# 1      Market Cap  6.035708e+11
# 0        PE Ratio  3.039568e+01

# %%
import yfinance as yf
import pandas as pd
from sqlalchemy import create_engine
import yfinance as yf
import psycopg2
from datetime import datetime

# %%
conn= psycopg2.connect(
        dbname="stockdata",
    user="postgres",
    password="admin",
    host="localhost",
    port="5432"

)
cursor = conn.cursor()

# %%
# ดึงข้อมูลหุ้น AOT.BK
stock = yf.Ticker("PTT.BK")
fundamental_data = stock.info

# สร้าง DataFrame
fundamental_df = pd.DataFrame({
    "Metric": ["PE Ratio", "Market Cap", "EPS", "Beta", "Dividend Yield"],
    "Value": [
        fundamental_data.get("trailingPE", "N/A"),
        fundamental_data.get("marketCap", "N/A"),
        fundamental_data.get("epsTrailingTwelveMonths", "N/A"),
        fundamental_data.get("beta", "N/A"),
        fundamental_data.get("dividendYield", "N/A")
    ]
})
print(fundamental_df)
# Out:
#            Metric         Value
# 0        PE Ratio  9.761905e+00
# 1      Market Cap  8.783122e+11
# 2             EPS  3.150000e+00
# 3            Beta  7.680000e-01
# 4  Dividend Yield  8.390000e+00

# %%
# ดึงข้อมูลหุ้น AOT.BK
symbol = "AOT.BK"
stock = yf.Ticker(symbol)
fundamental_data = stock.info

# ตรวจสอบว่ามีข้อมูลหรือไม่
if not fundamental_data or fundamental_data is None or "longName" not in fundamental_data:
    print(f"⚠️ ไม่มีข้อมูลของ {symbol} บน Yahoo Finance")
else:
    # บันทึกข้อมูลบริษัท
    company_info_query = """
    INSERT INTO company_info (
        symbol, company_name, sector, industry, address1, address2, city, zip, country, phone, fax, website, 
        long_business_summary, market_cap, total_revenue, net_income, created_at
    ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (symbol) DO UPDATE SET 
        market_cap = EXCLUDED.market_cap, 
        total_revenue = EXCLUDED.total_revenue, 
        net_income = EXCLUDED.net_income;
    """

    company_values = (
        symbol,
        fundamental_data.get("longName"),
        fundamental_data.get("sector"),
        fundamental_data.get("industry"),
        fundamental_data.get("address1"),
        fundamental_data.get("address2"),
        fundamental_data.get("city"),
        fundamental_data.get("zip"),
        fundamental_data.get("country"),
        fundamental_data.get("phone"),
        fundamental_data.get("fax"),
        fundamental_data.get("website"),
        fundamental_data.get("longBusinessSummary"),
        fundamental_data.get("marketCap"),
        fundamental_data.get("totalRevenue"),
        fundamental_data.get("netIncomeToCommon"),
        datetime.now()
    )

    cursor.execute(company_info_query, company_values)

    # บันทึกข้อมูลพื้นฐานของหุ้น
    fundamental_metrics = [
        ("PE Ratio", fundamental_data.get("trailingPE", "N/A")),
        ("Market Cap", fundamental_data.get("marketCap", "N/A")),
        ("EPS", fundamental_data.get("epsTrailingTwelveMonths", "N/A")),
        ("Beta", fundamental_data.get("beta", "N/A")),
        ("Dividend Yield", fundamental_data.get("dividendYield", "N/A"))
    ]

    fundamental_query = """
    INSERT INTO stock_fundamentals (symbol, metric, value, created_at) VALUES (%s, %s, %s, %s)
    """

    for metric, value in fundamental_metrics:
        cursor.execute(fundamental_query, (symbol, metric, str(value), datetime.now()))

    conn.commit()  # บันทึกข้อมูล
    print(f"✅ ข้อมูลของ {symbol} ถูกบันทึกเรียบร้อยแล้ว!")
# Out:
# ✅ ข้อมูลของ AOT.BK ถูกบันทึกเรียบร้อยแล้ว!

# %%
symbol = "AOT.BK"
stock = yf.Ticker(symbol)
fundamental_data = stock.info

# บันทึกข้อมูลบริษัท
company_info_query = """
INSERT INTO company_info (
    symbol, company_name, sector, industry, address1, address2, city, zip, country, phone, fax, website, 
    long_business_summary, market_cap, total_revenue, net_income, created_at
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
ON CONFLICT (symbol) DO UPDATE SET 
    market_cap = EXCLUDED.market_cap, 
    total_revenue = EXCLUDED.total_revenue, 
    net_income = EXCLUDED.net_income;
"""

company_values = (
    symbol,
    fundamental_data.get("longName"),
    fundamental_data.get("sector"),
    fundamental_data.get("industry"),
    fundamental_data.get("address1"),
    fundamental_data.get("address2"),
    fundamental_data.get("city"),
    fundamental_data.get("zip"),
    fundamental_data.get("country"),
    fundamental_data.get("phone"),
    fundamental_data.get("fax"),
    fundamental_data.get("website"),
    fundamental_data.get("longBusinessSummary"),
    fundamental_data.get("marketCap"),
    fundamental_data.get("totalRevenue"),
    fundamental_data.get("netIncomeToCommon"),
    datetime.now()
)

cursor.execute(company_info_query, company_values)

# บันทึกข้อมูลพื้นฐานของหุ้น
fundamental_metrics = [
    ("PE Ratio", fundamental_data.get("trailingPE", "N/A")),
    ("Market Cap", fundamental_data.get("marketCap", "N/A")),
    ("EPS", fundamental_data.get("epsTrailingTwelveMonths", "N/A")),
    ("Beta", fundamental_data.get("beta", "N/A")),
    ("Dividend Yield", fundamental_data.get("dividendYield", "N/A"))
]

fundamental_query = """
INSERT INTO stock_fundamentals (symbol, metric, value, created_at) VALUES (%s, %s, %s, %s)
"""

for metric, value in fundamental_metrics:
    cursor.execute(fundamental_query, (symbol, metric, str(value), datetime.now()))

# บันทึกข้อมูลผู้บริหาร
officers = fundamental_data.get("companyOfficers", [])
officer_query = """
INSERT INTO company_officers (
    symbol, name, age, title, fiscal_year, total_pay, exercised_value, unexercised_value, created_at
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

for officer in officers:
    cursor.execute(officer_query, (
        symbol,
        officer.get("name"),
        officer.get("age"),
        officer.get("title"),
        officer.get("fiscalYear"),
        officer.get("totalPay", 0),
        officer.get("exercisedValue", 0),
        officer.get("unexercisedValue", 0),
        datetime.now()
    ))



print("✅ ข้อมูลถูกบันทึกลงใน PostgreSQL เรียบร้อยแล้ว!")
# Out:
# ✅ ข้อมูลถูกบันทึกลงใน PostgreSQL เรียบร้อยแล้ว!

# %%
# 📥 โหลดรายชื่อหุ้นจาก CSV
try:
    symbols_df = pd.read_csv("thai_stocks_updated.csv")
    symbols = symbols_df['symbol'].dropna().tolist()
except FileNotFoundError:
    print("❌ ไม่พบไฟล์ 'thai_stocks.csv'")
    exit()

for symbol in symbols:
    try:
        stock = yf.Ticker(symbol)
        fundamental_data = stock.info

        # ✅ ตรวจสอบว่ามีข้อมูลหรือไม่
        if not fundamental_data or fundamental_data is None or "longName" not in fundamental_data:
            print(f"⚠️ ไม่มีข้อมูลของ {symbol} บน Yahoo Finance")
            continue

        with conn.cursor() as cursor:
            # บันทึกข้อมูลบริษัท
            company_info_query = """
            INSERT INTO company_info (
                symbol, company_name, sector, industry, address1, address2, city, zip, country, phone, fax, website, 
                long_business_summary, market_cap, total_revenue, net_income, created_at
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            ON CONFLICT (symbol) DO UPDATE SET 
                market_cap = EXCLUDED.market_cap, 
                total_revenue = EXCLUDED.total_revenue, 
                net_income = EXCLUDED.net_income;
            """

            company_values = (
                symbol,
                fundamental_data.get("longName"),
                fundamental_data.get("sector"),
                fundamental_data.get("industry"),
                fundamental_data.get("address1"),
                fundamental_data.get("address2"),
                fundamental_data.get("city"),
                fundamental_data.get("zip"),
                fundamental_data.get("country"),
                fundamental_data.get("phone"),
                fundamental_data.get("fax"),
                fundamental_data.get("website"),
                fundamental_data.get("longBusinessSummary"),
                fundamental_data.get("marketCap"),
                fundamental_data.get("totalRevenue"),
                fundamental_data.get("netIncomeToCommon"),
                datetime.now()
            )

            cursor.execute(company_info_query, company_values)

            # บันทึกข้อมูลพื้นฐานของหุ้น
            fundamental_metrics = [
                ("PE Ratio", fundamental_data.get("trailingPE", "N/A")),
                ("Market Cap", fundamental_data.get("marketCap", "N/A")),
                ("EPS", fundamental_data.get("epsTrailingTwelveMonths", "N/A")),
                ("Beta", fundamental_data.get("beta", "N/A")),
                ("Dividend Yield", fundamental_data.get("dividendYield", "N/A"))
            ]

            fundamental_query = """
            INSERT INTO stock_fundamentals (symbol, metric, value, created_at) VALUES (%s, %s, %s, %s)
            """

            for metric, value in fundamental_metrics:
                cursor.execute(fundamental_query, (symbol, metric, str(value), datetime.now()))

            # บันทึกข้อมูลผู้บริหาร
            officers = fundamental_data.get("companyOfficers", [])
            officer_query = """
            INSERT INTO company_officers (
                symbol, name, age, title, fiscal_year, total_pay, exercised_value, unexercised_value, created_at
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
            """

            for officer in officers:
                cursor.execute(officer_query, (
                    symbol,
                    officer.get("name"),
                    officer.get("age"),
                    officer.get("title"),
                    officer.get("fiscalYear"),
                    officer.get("totalPay", 0),
                    officer.get("exercisedValue", 0),
                    officer.get("unexercisedValue", 0),
                    datetime.now()
                ))

        conn.commit()  # ✅ Commit หลังจากหุ้นแต่ละตัวเสร็จสิ้น
        print(f"✅ ข้อมูลของ {symbol} ถูกบันทึกเรียบร้อยแล้ว!")

    except Exception as e:
        print(f"❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ {symbol}: {e}")
        continue

print("🎉 ข้อมูลหุ้นทั้งหมดถูกบันทึกลงใน PostgreSQL เรียบร้อยแล้ว!")
# Out:
# ✅ ข้อมูลของ 24CS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ 2S.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ 3BBIF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ A.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ A5.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AAI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AAV.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ABM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ACAP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ACC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ACE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ACG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ADB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ADD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ADVANC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ ADVICE.BK บน Yahoo Finance
# ✅ ข้อมูลของ AE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AEONTS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AFC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AGE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AHC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AIE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AIMCG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AIMIRT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AIRA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AJ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AJA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AKP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AKR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AKS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ALLA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ALLY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ALPHAX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ALT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ALUCON.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AMA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AMANAH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AMARC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AMARIN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AMATA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AMATAR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AMATAV.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AMC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AMR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ANAN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ ANI.BK บน Yahoo Finance
# ✅ ข้อมูลของ AOT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ APCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ APCS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ APO.BK บน Yahoo Finance
# ✅ ข้อมูลของ APP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ APURE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AQUA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ARIN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ARIP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ARROW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ASAP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ASEFA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ASIA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ASIAN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ASIMAR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ASK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ASN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ASP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ASW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ATP30.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AU.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AUCT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AURA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AWC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AXTRART.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ AYUD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ B.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ B52.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BAFS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BAM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BANPU.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BAREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BAY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BBGI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BBIK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BBL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BCH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BCP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BCPG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BCT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BDMS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BE8.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BEAUTY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BEC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BEM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BEYOND.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BGC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BGRIM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BGT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BIG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BIOTEC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BIS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BIZ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BJC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BJCHI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BKD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BKGI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BKIH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BLA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BLAND.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BLC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BLESS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BLISS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BOFFICE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BOL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BPP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ BPS.BK บน Yahoo Finance
# ✅ ข้อมูลของ BR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BRI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BROCK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BRR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BRRGIF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BSBM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BSM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ BSRC.BK บน Yahoo Finance
# ✅ ข้อมูลของ BTC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BTG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BTNC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BTS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BTSGIF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BTW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BUI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BVG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BWG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ B-WORK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ BYD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CAZ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CBG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CCET.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CCP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CEN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CENTEL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CEYE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CFARM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CFRESH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CGD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CGH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ CHAO.BK บน Yahoo Finance
# ✅ ข้อมูลของ CHARAN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CHASE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CHAYO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CHEWA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CHG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CHIC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CHO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CHOTI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CHOW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CIG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CIMBT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CITY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CIVIL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CKP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CMAN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CMC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CMO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CMR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CNT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ COCOCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ COLOR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ COM7.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ COMAN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPALL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPANEL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPAXT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPNCG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPNREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPTREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CPW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CRANE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CRC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CRD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CREDIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CSC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CSP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CSR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CSS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CTARAF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CTW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CV.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ CWT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ D.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DCC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DCON.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DDD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DELTA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DEMCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DEXON.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DHOUSE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DIF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DIMET.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DITTO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DMT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DOD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DOHOME.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DPAINT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DRT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DTCENT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DTCI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DUSIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ DV8.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EASON.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EASTW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ECF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ECL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EFORL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EGATIF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EGCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EKH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EMC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ EPG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ERW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ESTAR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ETC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ETE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ ETL.BK บน Yahoo Finance
# ⚠️ ไม่มีข้อมูลของ EURO.BK บน Yahoo Finance
# ✅ ข้อมูลของ EVER.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ F&D.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FANCY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FLOYD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ FM.BK บน Yahoo Finance
# ✅ ข้อมูลของ FMT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FNS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FORTH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FPI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FPT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FSMART.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FSX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FTE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FTI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FTREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FUTURERT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ FVC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GABLE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GAHREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GBX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GCAP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GEL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GENCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GFC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GFPT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GGC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GJS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GLAND.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GLOBAL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GLOCON.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GLORY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GPI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GPSC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GRAMMY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GRAND.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GREEN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GROREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GSTEEL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GTB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GTV.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GULF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GUNKUL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GVREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ GYT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HANA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HARN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HEALTH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HENG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HFT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HMPRO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HPF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HPT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HTC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HTECH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HUMAN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HYDRO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ HYDROGEN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ I2.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ICC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ICHI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ICN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IFS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IHL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IIG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ III.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ILINK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ILM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IMH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IMPACT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IND.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ INET.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ INETREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ INGRS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ INOX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ INSET.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ INSURE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ INTUCH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IRC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IRCP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ IROYAL.BK บน Yahoo Finance
# ✅ ข้อมูลของ IRPC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ISSARA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ IT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ITC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ITD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ITEL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ITNS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ITTHI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ IVF.BK บน Yahoo Finance
# ✅ ข้อมูลของ IVL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ J.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JAK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JAS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JCK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JCKH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JCT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JDF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JKN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JMART.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JMT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JPARK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JSP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JTS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ JUBILE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ K.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KAMART.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KASET.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KBANK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KBS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KBSPIF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KCAR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KCC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KCE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KCG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KCM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KDH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KEX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KGEN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KGI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KIAT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KISS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KJL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KKC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KKP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KLINIQ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KOOL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KPNREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KSL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KTB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KTBSTMR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KTC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KTIS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KTMS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KUMWEL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KUN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KWC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KWI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KWM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ KYE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ L&E.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LALIN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LANNA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LDC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LEE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LEO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LHFG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LHHOTEL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LHK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LHRREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LHSC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LOXLEY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LPH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LPN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LRH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ LST.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ LTS.BK บน Yahoo Finance
# ✅ ข้อมูลของ LUXF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ M.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MAGURO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MAJOR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MALEE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MANRIN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MASTER.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MATCH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MATI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MBAX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MBK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ MCA.BK บน Yahoo Finance
# ✅ ข้อมูลของ M-CHAI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MCOT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MCS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MDX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MEB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ MEDEZE.BK บน Yahoo Finance
# ✅ ข้อมูลของ MEGA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MENA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ META.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ METCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MFC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MFEC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MGC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ MGI.BK บน Yahoo Finance
# ✅ ข้อมูลของ MGT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MICRO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MIDA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MII.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MILL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MINT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MIPF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MITSIB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MJD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MJLF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ML.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MNIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MNIT2.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MNRF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MODERN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MONO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MOONG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MORE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MOSHI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ MOTHER.BK บน Yahoo Finance
# ✅ ข้อมูลของ M-PAT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MPJ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MSC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MST.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ M-STOR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MTC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MTI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MTW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MUD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ MVP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ NAM.BK บน Yahoo Finance
# ⚠️ ไม่มีข้อมูลของ NAT.BK บน Yahoo Finance
# ✅ ข้อมูลของ NATION.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NCAP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NCH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NCL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NCP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NDR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ NEO.BK บน Yahoo Finance
# ✅ ข้อมูลของ NEP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NER.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NETBAY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NEW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NEWS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NEX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NFC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NKI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NKT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NNCL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NOBLE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NOVA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NPK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NRF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NSL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NTSC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NTV.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NV.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NVD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NWR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ NYT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ OCC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ OGC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ OHTL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ OKJ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ONEE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ OR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ORI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ ORN.BK บน Yahoo Finance
# ✅ ข้อมูลของ OSP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PACO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PAF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ PANEL.BK บน Yahoo Finance
# ✅ ข้อมูลของ PAP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PATO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PCC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PCE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PCSGH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PDG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PDJ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PEACE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PEER.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PERM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PHG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PHOL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PICO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PIMO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PIN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PIS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PJW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PLANB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PLANET.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PLAT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PLE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PLT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PLUS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PMC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PMTA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ POLY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ POPF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PORT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PPM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PPP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PPPM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PPS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PQS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PR9.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRAKIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRAPAT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PREB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRECHA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRIME.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRIN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRINC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PROEN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PROS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PROSPECT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PROUD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PRTR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PSG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PSH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PSL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PSP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PSTC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PTC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PTECH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PTG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PTL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PTT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PTTEP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PTTGC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ PYLON.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ Q-CON.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ QH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ QHBREIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ QHHRREIT.BK: Too Many Requests. Rate limited. Try after a while.
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/QHOP.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=QHOP.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ QHOP.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/QLT.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=QLT.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ QLT.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/QTC.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=QTC.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ QTC.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/QTCG.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=QTCG.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ QTCG.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RABBIT.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RABBIT.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ RABBIT.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RAM.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RAM.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ RAM.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RATCH.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RATCH.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ RATCH.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RBF.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RBF.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ RBF.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RCL.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RCL.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ RCL.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/READY.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=READY.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ READY.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RICHY.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RICHY.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ RICHY.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RJH.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RJH.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ RJH.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RML.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RML.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ RML.BK: 'NoneType' object has no attribute 'update'
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ROCK.BK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ROCK.BK&crumb=Edge%3A+Too+Many+Requests
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของ ROCK.BK: 'NoneType' object has no attribute 'update'
# ✅ ข้อมูลของ ROCTEC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ROH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ROJNA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ RP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ RPC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ RPH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ RS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ RSP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ RSXYZ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ RT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ RWI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ S.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ S&J.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ S11.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAAM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SABINA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SABUY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAFARI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAFE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SALEE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAMART.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAMCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAMTEL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SANKO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAPPE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAUCE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAV.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAWAD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SAWANG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SCAP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SCB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SCC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SCCC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SCG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ SCGD.BK บน Yahoo Finance
# ✅ ข้อมูลของ SCGP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SCI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ SCL.BK บน Yahoo Finance
# ✅ ข้อมูลของ SCM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SCN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SCP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SDC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SEAFCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SEAOIL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SECURE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SE-ED.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ SEI.BK บน Yahoo Finance
# ✅ ข้อมูลของ SELIC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SENA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SENX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SFLEX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SFT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SGC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SGF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SGP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SHANG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SHR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SIAM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SICT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SIMAT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SINGER.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SINO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SIRI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SIRIPRT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SIS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SISB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SITHAI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SJWD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SKE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SKN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SKR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SKY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SLP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SMART.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SMD100.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SMIT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SMPC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SMT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SNC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SNNP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SNP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ SNPS.BK บน Yahoo Finance
# ✅ ข้อมูลของ SO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SOLAR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SONIC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SORKON.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SPA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SPACK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SPALI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SPC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SPCG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SPG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SPI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SPRC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ SPREME.BK บน Yahoo Finance
# ✅ ข้อมูลของ SPRIME.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SPVI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SQ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SRICHA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SRIPANWA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SRS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SSF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SSP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SSPF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SSSC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SST.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SSTRT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STANLY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STECH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STECON.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STELLA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STGT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STOWER.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ STPI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ STX.BK บน Yahoo Finance
# ✅ ข้อมูลของ SUC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SUN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SUPER.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SUPEREIF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SUSCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SUTHA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SVI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SVOA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SVR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SVT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SWC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SYMC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SYNEX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ SYNTEC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TACC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TAE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TAKUNI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TAN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TAPAC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TASCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TATG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TBN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TCAP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TCC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TCJ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TCMC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TCOAT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TEAM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TEAMG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TEGH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TEKA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ TERA.BK บน Yahoo Finance
# ✅ ข้อมูลของ TFFIF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TFG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TFI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TFM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TFMAMA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TGE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TGH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TGPRO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THAI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THANA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THANI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THCOM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THIP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THMUI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THRE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ THREL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TIDLOR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TIF1.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TIGER.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TIPCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TIPH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TISCO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TITLE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TKC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TKN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TKS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TKT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TLHPF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TLI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ TMAN.BK บน Yahoo Finance
# ✅ ข้อมูลของ TMC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TMD.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TMI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TMILL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TMT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TMW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TNDT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TNH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TNITY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TNL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TNP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TNPC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TNPF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TNR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TOA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TOG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TOP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TOPP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPAC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPBI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPCH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPCS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPIPL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPIPP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPLAS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPOLY.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPRIME.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TPS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TQM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TQR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TRC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TRITN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ TRP.BK บน Yahoo Finance
# ✅ ข้อมูลของ TRT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TRU.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TRUBB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TRUE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TRV.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TSC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TSE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TSI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TSR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TSTE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TSTH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TTA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TTB.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TTCL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TTI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TTLPF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TTT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TTW.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TU.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TU-PF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TURTLE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TVDH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TVH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TVO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TVT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TWP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TWPC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TWZ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ TYCN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UAC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UBA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UBE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UBIS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UEC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UKEM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UMI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UMS.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UNIQ.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UOBKH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UPF.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UPOIC.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UREKA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UTP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UV.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ UVAN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ VARO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ VCOM.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ VGI.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ VIBHA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ VIH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ VL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ VNG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ VPO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ VRANDA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ VS.BK บน Yahoo Finance
# ✅ ข้อมูลของ WACOAL.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WARRIX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WAVE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ WELL.BK บน Yahoo Finance
# ✅ ข้อมูลของ WFX.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WGE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WHA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WHABT.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WHAIR.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WHART.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WHAUP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WICE.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WIIK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WIN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ⚠️ ไม่มีข้อมูลของ WINDOW.BK บน Yahoo Finance
# ✅ ข้อมูลของ WINMED.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WINNER.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WORK.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WP.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ WPH.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ XBIO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ XO.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ XPG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ YGG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ YONG.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ YUASA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ZAA.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ZEN.BK ถูกบันทึกเรียบร้อยแล้ว!
# ✅ ข้อมูลของ ZIGA.BK ถูกบันทึกเรียบร้อยแล้ว!
# 🎉 ข้อมูลหุ้นทั้งหมดถูกบันทึกลงใน PostgreSQL เรียบร้อยแล้ว!

# %%
# Query ข้อมูลจากตาราง stock_fundamentals
query = "SELECT * FROM public.stock_fundamentals;"

# ดึงข้อมูลเป็น DataFrame
df_db = pd.read_sql(query, conn)
print(df_db.head())
# Out:
#    id  symbol          metric         value                 created_at
# 0   1  AOT.BK        PE Ratio     28.597122 2025-03-05 01:03:13.360479
# 1   2  AOT.BK      Market Cap  567856594944 2025-03-05 01:03:13.362489
# 2   3  AOT.BK             EPS          1.39 2025-03-05 01:03:13.362489
# 3   4  AOT.BK            Beta          0.36 2025-03-05 01:03:13.362489
# 4   5  AOT.BK  Dividend Yield          1.87 2025-03-05 01:03:13.362489
# C:\Users\Imron\AppData\Local\Temp\ipykernel_18504\1382985433.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_db = pd.read_sql(query, conn)

# %%
import matplotlib.pyplot as plt
import numpy as np

# ตัวอย่างข้อมูลหุ้น (สมมติว่าข้อมูลดึงมาจากฐานข้อมูลแล้ว)
data = {
    "symbol": ["AOT.BK", "PTT.BK", "SCB.BK", "CPALL.BK", "KBANK.BK"],
    "PE Ratio": [30.4, 12.8, 9.5, 27.3, 8.6],
    "EPS": [1.39, 5.22, 8.75, 3.55, 7.89],
    "Market Cap": [603570831360, 1200000000000, 500000000000, 750000000000, 620000000000],
}

df_viz = pd.DataFrame(data)

# สร้างกราฟแท่งเปรียบเทียบ PE Ratio / EPS / Market Cap
fig, ax = plt.subplots(figsize=(10, 6))
width = 0.2  # ความกว้างของแท่ง

x = np.arange(len(df_viz["symbol"]))  # ตำแหน่งของหุ้น

# วาดกราฟแท่ง
ax.bar(x - width, df_viz["PE Ratio"], width, label="PE Ratio")
ax.bar(x, df_viz["EPS"], width, label="EPS")
ax.bar(x + width, df_viz["Market Cap"] / 1e12, width, label="Market Cap (T THB)")

# ตั้งค่ากราฟ
ax.set_xticks(x)
ax.set_xticklabels(df_viz["symbol"])
ax.set_ylabel("Value")
ax.set_title("Comparison of PE Ratio, EPS, and Market Cap")
ax.legend()

# แสดงกราฟ
plt.show()
